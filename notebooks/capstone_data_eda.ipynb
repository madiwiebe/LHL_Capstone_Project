# %%
import pandas as pd
import os

# %%
path = "D:/School/LHL/Capstone project data/pcds_data"

# %%
folders = os.listdir(path)

# %%
for folder in folders:
    files = os.listdir(f"{path}/{folder}")
    for file in files:
        station_data = pd.read_csv(f"{path}/{folder}/{file}")

# %% [markdown]
# - unzip folder

# %%
station_metadata = pd.read_csv(r"C:\Users\maddy\Downloads\climate-stations.csv")
station_metadata
# Out:
#                x          y  STN_ID         STATION_NAME PROV_STATE_TERR_CODE  \
# 0    -101.233333  50.416667    3490          FORT ELLICE                   MB
# 1    -101.150000  50.516667    3491            FOXWARREN                   MB
# 2    -100.550000  49.916667    3501             HILLVIEW                   MB
# 3    -100.633333  50.100000    3513               OAKNER                   MB
# 4    -101.100000  49.550000    3524               RESTON                   MB
# ...          ...        ...     ...                  ...                  ...
# 8547  -79.546403  43.090845   28037           SMITHVILLE                   ON
# 8548  -81.366667  43.033333   28071            LONDON NW                   ON
# 8549  -72.060833  46.303611   29714              LEMIEUX                   QC
# 8550  -68.200000  49.133333   30173        BAIE-COMEAU A                   QC
# 8551  -79.395000  43.628611   30247  TORONTO CITY CENTRE                   ON
#
# ...

# %%
station_metadata_bc = station_metadata.loc[station_metadata["PROV_STATE_TERR_CODE"]=="BC", ["STN_ID","LATITUDE","LONGITUDE","PROV_STATE_TERR_CODE"]]
station_metadata_bc = station_metadata_bc.reset_index(drop=True)
station_metadata_bc
# Out:
#       STN_ID   LATITUDE   LONGITUDE PROV_STATE_TERR_CODE
# 0      52278  494443000 -1145258000                   BC
# 1       1362  511600000 -1173000000                   BC
# 2       1407  550400000 -1210700000                   BC
# 3       1416  560500000 -1215500000                   BC
# 4       1418  560132003 -1215442001                   BC
# ...      ...        ...         ...                  ...
# 1745    1020  500700000 -1204800000                   BC
# 1746    1038  491100000 -1193200000                   BC
# 1747   49548  505729600 -1181034600                   BC
# 1748   51337  483850000 -1232533000                   BC
# 1749   26991  495200000 -1193500000                   BC
#
# [1750 rows x 4 columns]
